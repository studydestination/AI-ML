# %%
import pandas as pd 
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sneha\OneDrive\AIML\First\first_venv\python.exe

# %% [markdown]
# # Dataset info

# %%
df = pd.read_csv('data/stud.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('data/stud.csv')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.shape

# %% [markdown]
# # check missing values

# %%
df.isna().sum()

# %% [markdown]
# # check duplicates

# %%
df.duplicated().sum()

# %% [markdown]
# # check data types

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Check number of unique values of each column

# %%
df.nunique()

# %% [markdown]
# # check statistics of each column

# %%
df.describe()

# %% [markdown]
# # EDA
